# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import norm
from simulator.monte_carlo import MonteCarloSimulator

# %%
df = pd.read_pickle("example_stock.pickle")

# %%
msc = MonteCarloSimulator()
T = 3*252
t_ahead = 252

out = msc.simulat_steps(df , T = T, t_ahead = t_ahead, model = "brownian", nb_sim = 1000)
print(out)
# Out:
# {'start': 16.65, 'mean': 31.23639623987858, '5%': 7.6761223837217685, '95%': 77.31169639424202}

# %%
out = msc.simulat_steps(df , T = T, t_ahead = t_ahead, model = "norm", nb_sim = 1000)
print(out)
# Out:
# {'start': 16.65, 'mean': 37.7710608471169, '5%': 9.563569371200645, '95%': 91.53324514108863}
